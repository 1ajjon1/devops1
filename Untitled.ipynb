# %%
pip install pyyaml
# Out:
# Requirement already satisfied: pyyaml in c:\users\taleiven\anaconda3\lib\site-packages (6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from github import Github
import yaml

data = yaml.safe_load(open("credentials.yml"))


user = data["creds"]["username"]
token = data["creds"]["token"]


g = Github(token)

repo = g.get_repo("1ajjon1/devops1")
lst = list(repo.get_branches())
print(lst)
# Out:
# [Branch(name="main")]
